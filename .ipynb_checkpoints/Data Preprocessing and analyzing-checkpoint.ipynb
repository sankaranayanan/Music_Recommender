# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('music.csv')

# %%
df.columns
# Out:
# Index(['id', 'track_name', 'album_name', 'album_id', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'artist_id',
#        'artist_name'],
#       dtype='object')

# %%
df.head()
# Out:
#                        id                track_name       album_name  \
# 0  63dMNGUUu7rXX0NZYVO3Tm  Time - Alan Walker Remix  World Of Walker
# 1  0zqBZqm5czQ3A4EoSdKFHj           Man On The Moon  World Of Walker
# 2  28VbwtsYnj85UEODGpQRem             Alone, Pt. II  World Of Walker
# 3  2sVcG5mresyV79qpYr3M1C                  Paradise  World Of Walker
# 4  1ez5ood0PsYP4Yi6KhYe7H               Out Of Love  World Of Walker
#
#                  album_id  danceability  energy  key  loudness  mode  \
# 0  3KrkQ77DF9OUB0aOzKFYOF         0.575   0.941    7    -7.908     1
# 1  3KrkQ77DF9OUB0aOzKFYOF         0.668   0.816    4    -5.648     0
# 2  3KrkQ77DF9OUB0aOzKFYOF         0.673   0.659    3    -4.493     0
# 3  3KrkQ77DF9OUB0aOzKFYOF         0.779   0.580    0    -6.168     0
# 4  3KrkQ77DF9OUB0aOzKFYOF         0.677   0.723    4    -5.474     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
sns.heatmap(df2.isna(),yticklabels=False,linewidths='0')
# Out:
# <AxesSubplot:>

# %%
df['artist_name'].unique()
# Out:
# array(['Alan Walker', 'Camila Cabello', 'Ed Sheeran', 'Justien Bieber',
#        'Lin-Manuel Miranda', 'Maroon 5', 'Shawn Mendes', 'Weekend',
#        'ariana grande', 'Selena Gomez', 'Halsey', 'Sia', 'lil nas x',
#        'Taylor Swift'], dtype=object)

# %%
df2 = df[['danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo']]

# %%
sns.set(rc = {'figure.figsize':(25,10)})
sns.barplot(y=df2['danceability'],x=df['artist_name'])
# Out:
# <AxesSubplot:xlabel='artist_name', ylabel='danceability'>

# %%
sns.barplot(y=df2['energy'],x=df['artist_name'])
# Out:
# <AxesSubplot:xlabel='artist_name', ylabel='energy'>

# %%
sns.set(rc = {'figure.figsize':(15,20)})
sns.pairplot(df2)

# %%
sns.set(rc = {'figure.figsize':(25,10)})
sns.boxplot(y=df2['energy'],x=df['artist_name'])
# Out:
# <AxesSubplot:xlabel='artist_name', ylabel='energy'>

# %%
sns.jointplot(y=df2['instrumentalness'],x=df['speechiness'],kind="scatter")

# %% [markdown]
# # Content based filtering

# %%
search = dict(df2.iloc[1318])

# %%
def findsimilarity():
    df2['euc_dst'] = np.sqrt((df2['danceability']-search['danceability'])**2 + (df2['energy']-search['energy'])**2 +(df2['key']-search['key'])**2+(df2['loudness']-search['loudness'])**2+(df2['mode']-search['mode'])**2+(df2['speechiness']-search['speechiness'])**2+(df2['acousticness']-search['acousticness'])**2+(df2['instrumentalness']-search['instrumentalness'])**2+(df2['liveness']-search['liveness'])**2+(df2['valence']-search['valence'])**2+(df2['tempo']-search['tempo'])**2)

# %%
findsimilarity()
# Out:
# C:\Users\Sankar\AppData\Local\Temp/ipykernel_2956/807437484.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['euc_dst'] = np.sqrt((df2['danceability']-search['danceability'])**2 + (df2['energy']-search['energy'])**2 +(df2['key']-search['key'])**2+(df2['loudness']-search['loudness'])**2+(df2['mode']-search['mode'])**2+(df2['speechiness']-search['speechiness'])**2+(df2['acousticness']-search['acousticness'])**2+(df2['instrumentalness']-search['instrumentalness'])**2+(df2['liveness']-search['liveness'])**2+(df2['valence']-search['valence'])**2+(df2['tempo']-search['tempo'])**2)

# %%
sns.set(rc = {'figure.figsize':(10,5)})
sns.heatmap(df2.isna(),yticklabels=False,linewidths='0')
# Out:
# <AxesSubplot:>

# %%
df2.nsmallest(5,['euc_dst'])
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1318         0.593   0.503    8    -6.725     0       0.2200        0.2930
# 1121         0.207   0.669    9    -7.326     0       0.0458        0.0163
# 49           0.494   0.502    8    -5.750     1       0.0329        0.2530
# 387          0.711   0.608    7    -6.934     1       0.3740        0.0529
# 390          0.705   0.587    7    -7.137     1       0.4510        0.0411
#
#       instrumentalness  liveness  valence    tempo   euc_dst
# 1318          0.000000    0.4050    0.710  178.781  0.000000
# 1121          0.002880    0.5010    0.154  179.352  1.512965
# 49            0.000004    0.1050    0.162  179.643  1.769288
# 387           0.000100    0.0605    0.500  179.973  1.932262
# 390           0.000000    0.0411    0.417  179.967  1.982682

# %%
df.iloc[49]
# Out:
# id                  7cHje4KLujM18aBSLvaySE
# track_name                       This Love
# album_name                         Romance
# album_id            3Vsbl0diFGw8HNSjG8ue9m
# danceability                         0.494
# energy                               0.502
# key                                      8
# loudness                             -5.75
# mode                                     1
# speechiness                         0.0329
# acousticness                         0.253
# instrumentalness                  0.000004
# liveness                             0.105
# valence                              0.162
# tempo                              179.643
# artist_id           4nDoRrQiYLoBzwC5BhVJzF
# artist_name                 Camila Cabello
# Name: 49, dtype: object
