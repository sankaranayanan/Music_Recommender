# %% [markdown]
# # Phase:1 Data Extraction

# %% [markdown]
# Install the spotipy library using the pip command<br>
# &emsp;1.pip install spotipy<br>
# Enter the spotify client_id and client_secret of your account to access the Api.<br>
# &emsp;2.Refer : https://developer.spotify.com/dashboard/<br>
# &emsp;&ensp;&ensp;Sign in with your account and create an app.<br>
# &emsp;&ensp;&ensp;enter the app to access your client_id and client_secret<br>

# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
client_id = "YYYY"
client_secret = "XXXX"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
import requests
import pandas as pd
import time

# %% [markdown]
# Create a connection to the Api

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %% [markdown]
# After sucessfull connection enter you favourite artist in the artist_id<br>
# &emsp;right click artist profile-->share link --> copy link to artist <br>
# &emsp;Example : https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx?si=0b1c0f5d36014512<br>
# &emsp;Here 0C8ZW7ezQVs4URX5aX7Kqx is the artist id for selena gomez<br>

# %%
BASE_URL = 'https://api.spotify.com/v1/'

# your artist ID - The Weeknd
artist_id = '1Xyo4u8uXC1ZmMpatF05PJ'

# extract all albums
r = requests.get(BASE_URL + 'artists/' + artist_id + '/albums', 
                 headers=headers, 
                 params={'include_groups': 'album', 'limit': 50})
d = r.json()

# %% [markdown]
# Extract the data from the api response into a list

# %%
audiofeature = []   # will hold all audio feature info
albums = [] # to keep track of duplicates

# loop over albums and get all tracks
for album in d['items']:
    album_name = album['name']

    # here's a hacky way to skip over albums we've already grabbed
    trim_name = album_name.split('(')[0].strip()
    if trim_name.upper() in albums:
        continue
    albums.append(trim_name.upper()) # use upper() to standardize
    
    # this takes a few seconds so let's keep track of progress    
    print(album_name)
    
    # pull all tracks from this album
    r = requests.get(BASE_URL + 'albums/' + album['id'] + '/tracks', 
        headers=headers)
    tracks = r.json()['items']
    
    for track in tracks:
        # get audio features (key, liveness, danceability, ...)
        f = requests.get(BASE_URL + 'audio-features/' + track['id'], 
            headers=headers)
        f = f.json()
        
        # combine with album info
        f.update({
            'track_name': track['name'],
            'album_name': album_name,
            'release_date': album['release_date'],
            'album_id': album['id']
        })
        
        audiofeature.append(f)
# Out:
# Dawn FM (Alternate World)
# After Hours (Deluxe)
# My Dear Melancholy,
# Starboy
# Beauty Behind The Madness
# Kiss Land (Deluxe)
# Trilogy
# Echoes Of Silence (Original)
# Thursday (Original)
# House Of Balloons (Original)

# %%
'''

Create a dataFrame with the list

'''

df2 = pd.DataFrame(audiofeature)
df2.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.280   0.478    9    -8.755     0       0.0370      0.674000
# 1         0.728   0.741    6    -7.075     0       0.0473      0.000582
# 2         0.805   0.498    7    -7.927     0       0.0737      0.020300
# 3         0.698   0.769    8    -7.154     1       0.0368      0.012800
# 4         0.735   0.795   11    -6.523     0       0.1130      0.029600
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.000058    0.4830   0.0807  ...  71h3L4e8j3bwMpjfjteAYE
# 1          0.002060    0.3300   0.3100  ...  13WW1ZalDNFmKt4R8XhsGi
# 2          0.000024    0.0850   0.6360  ...  7uGX8wm0pIenP3XVEhOYQ0
# 3          0.001660    0.2380   0.3540  ...  1dyMD7bkPNIrwbHXjdLAls
# 4          0.000032    0.0678   0.9050  ...  3r7OYSMC4p5YTyjCplXOaQ
#
#                                     uri  \
# 0  spotify:track:71h3L4e8j3bwMpjfjteAYE
# 1  spotify:track:13WW1ZalDNFmKt4R8XhsGi
# 2  spotify:track:7uGX8wm0pIenP3XVEhOYQ0
# 3  spotify:track:1dyMD7bkPNIrwbHXjdLAls
# 4  spotify:track:3r7OYSMC4p5YTyjCplXOaQ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/71h3L4e8j3bw...
# 1  https://api.spotify.com/v1/tracks/13WW1ZalDNFm...
# 2  https://api.spotify.com/v1/tracks/7uGX8wm0pIen...
# 3  https://api.spotify.com/v1/tracks/1dyMD7bkPNIr...
# 4  https://api.spotify.com/v1/tracks/3r7OYSMC4p5Y...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/71h3...       96240
# 1  https://api.spotify.com/v1/audio-analysis/13WW...      212166
# 2  https://api.spotify.com/v1/audio-analysis/7uGX...      214215
# 3  https://api.spotify.com/v1/audio-analysis/1dyM...      339023
# 4  https://api.spotify.com/v1/audio-analysis/3r7O...      188918
#
#   time_signature                  track_name                 album_name  \
# 0              4                     Dawn FM  Dawn FM (Alternate World)
# 1              4                    Gasoline  Dawn FM (Alternate World)
# 2              4  How Do I Make You Love Me?  Dawn FM (Alternate World)
# 3              4              Take My Breath  Dawn FM (Alternate World)
# 4              4                   Sacrifice  Dawn FM (Alternate World)
#
#   release_date                album_id
# 0   2022-01-07  2JPcP8HUk2vm7Q8eDJlj0a
# 1   2022-01-07  2JPcP8HUk2vm7Q8eDJlj0a
# 2   2022-01-07  2JPcP8HUk2vm7Q8eDJlj0a
# 3   2022-01-07  2JPcP8HUk2vm7Q8eDJlj0a
# 4   2022-01-07  2JPcP8HUk2vm7Q8eDJlj0a
#
# [5 rows x 22 columns]

# %%
'''

Extract the required columns alone to another DataFrame

'''

df3 = pd.DataFrame(data=df2[['id','track_name', 'album_name','album_id','danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']],columns=['id','track_name', 'album_name','album_id','danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'],)

# %%
'''

Write the DataFrame into the same directory as your .ipynb file as a csv file with index set to false

'''
import os 
df3.to_csv('music_weekend.csv',index=False)
